# %% [markdown]
# <a href="https://colab.research.google.com/github/WindiDwi/VisualisasiData/blob/main/UASWindiDwiWidayanti.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install xlrd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: xlrd in /usr/local/lib/python3.10/dist-packages (2.0.1)

# %%
import pandas as pd

# %%
# reading the database
data = pd.read_csv("/content/kebutuhan_per_bulan_2.csv")

# printing the top 10 rows
display(data.head(10))
# Out:
#                Propinsi  tahun kebutuhan
# 0                  ACEH   2005    619876
# 1        SUMATERA UTARA   2005    547255
# 2        SUMATERA BARAT   2005    501315
# 3                  RIAU   2005    551498
# 4                 JAMBI   2005    495242
# 5      SUMATERA SELATAN   2005    495242
# 6              BENGKULU   2005    480000
# 7               LAMPUNG   2005    396456
# 8  KEP. BANGKA BELITUNG   2005    690000
# 9             KEP. RIAU   2005    552045

# %%
import pandas as pd
import matplotlib.pyplot as plt


x = data['tahun']
y = data['Propinsi']

plt.scatter(x,y)

plt.plot(x, y, color ='g', linestyle = 'dashed')

plt.xticks(rotation = 25)
plt.xlabel('Tahun')
plt.ylabel('Propinsi')
plt.title('Kebutuhan Per Bulan', fontsize = 12)
plt.grid()

plt.show()

# %%
import pandas as pd

# %%
# reading the database
data = pd.read_csv("/content/profile_pelanggan.csv")

# printing the top 10 rows
display(data.head(10))
# Out:
#    15572  DKI Jakarta
# 0  12461   Jawa Timur
# 1  12590   Jawa Barat
# 2  16839  DKI Jakarta
# 3  13596  DKI Jakarta
# 4  12395    Luar Jawa
# 5  15555  DKI Jakarta
# 6  16940  DKI Jakarta
# 7  14719  DKI Jakarta
# 8  15436  DKI Jakarta
# 9  15189  DKI Jakarta

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

data = pd.read_csv("/content/profile_pelanggan.csv")
data
x = data['15572']
y = data['DKI Jakarta']
plt.plot(x,y,'o')

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("/content/transaksi2.csv")

plt.scatter(data['22704'], data['25'], c=data['15572'])

plt.title('Transaksi')
plt.xlabel('Number')
plt.ylabel('Jumlah')



plt.show()
